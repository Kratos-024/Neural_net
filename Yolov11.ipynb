# %%
# !nvidia-smi
# Out:
# Sat Nov  8 14:53:28 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 86.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 111.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="yop8rDSIfeLoO7ELwSZD")
project = rf.workspace("first-yolo-baeua").project("tf-id-apfyp")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# Extracting Dataset Version Zip to TF-ID-1 in yolov11:: 100%|██████████| 9372/9372 [00:17<00:00, 534.05it/s]

# %%
# !pip install supervision ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.2/207.2 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.5 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.8/112.6 GB disk)

# %%
from IPython.display import Image

# %%
Image('/content/11.jpg')

# %%
import PIL
import ultralytics
model = ultralytics.YOLO('yolo11n.pt')
img = PIL.Image.open('/content/11.jpg')
pred = model.predict(img)
# Out:
# 0: 640x512 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)

# %%
pred[0].orig_img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
pred[0].names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
# ...

# %%
dataset.location
# Out:
# '/content/TF-ID-1'

# %%
# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs=10 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt source={dataset.location}/test/images
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/468 /content/TF-ID-1/test/images/arxiv_2305_02412_3_png.rf.b060020fb35ec451f8e9e8844350480b.jpg: 640x512 2 figures, 48.1ms
# image 2/468 /content/TF-ID-1/test/images/arxiv_2305_02412_5_png.rf.07ad71085a9f790206e70fd68fc8adb8.jpg: 640x512 1 figure, 1 table, 8.3ms
# image 3/468 /content/TF-ID-1/test/images/arxiv_2305_02412_6_png.rf.241785a46942b060a1430921c0b3e214.jpg: 640x512 (no detections), 8.3ms
# image 4/468 /content/TF-ID-1/test/images/arxiv_2305_02549_0_png.rf.e7c63a1769e57edbf7c2a54bd257cd37.jpg: 640x480 1 table, 48.7ms
# image 5/468 /content/TF-ID-1/test/images/arxiv_2305_02968_6_png.rf.16a6217b5c804e60491479b22d7ad53d.jpg: 640x512 3 figures, 8.7ms
# image 6/468 /content/TF-ID-1/test/images/arxiv_2305_02968_8_png.rf.440b2d72b1d7af4dc0a7546a9d0dfa16.jpg: 640x512 (no detections), 8.7ms
# ...

# %%
img1='/content/TF-ID-1/test/images/arxiv_2305_02412_5_png.rf.07ad71085a9f790206e70fd68fc8adb8.jpg'
img2='/content/runs/detect/predict/arxiv_2305_02412_5_png.rf.07ad71085a9f790206e70fd68fc8adb8.jpg'

# %%
img  = PIL.Image.open(img2)

# %%
img.resize((800,600))
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>
