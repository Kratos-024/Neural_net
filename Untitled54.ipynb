# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 75.5 MB/s eta 0:00:00
# ...

# %%
import gensim.downloader as api
model = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
words_vector = model

# %%
words_vector.word_vec('Dog').shape
# Out:
# /tmp/ipython-input-3750272734.py:1: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   words_vector.word_vec('Dog').shape
# (300,)

# %%
Domestic = words_vector.most_similar('Domestic')
tiger = words_vector.most_similar('Tiger')

# %%
words_vector.most_similar(positive=['King',"Woman"],negative=['Man'])
# Out:
# [('Queen', 0.4929387867450714),
#  ('Tupou_V.', 0.45174285769462585),
#  ('Oprah_BFF_Gayle', 0.4422132968902588),
#  ('Jackson', 0.440250426530838),
#  ('NECN_Alison', 0.4331282675266266),
#  ('Whitfield', 0.42834725975990295),
#  ('Ida_Vandross', 0.42084527015686035),
#  ('prosecutor_Dan_Satterberg', 0.420758992433548),
#  ('martin_Luther_King', 0.42059651017189026),
#  ('Coretta_King', 0.4202733635902405)]
